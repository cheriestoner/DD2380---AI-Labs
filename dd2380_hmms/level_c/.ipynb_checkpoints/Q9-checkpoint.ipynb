# %%
from player import HMM
from constants import *
K = 4

# %%
with open('hmm_c_N1000.in') as inp:
    obs_list = list(map(int, inp.readline().split()))
with open('hmm_c_N10000.in') as inp2:
    obs_list_2 = list(map(int, inp2.readline().split()))
obs = obs_list[1:]
obs_2 = obs_list_2[1:]

# %%
for n_states in range(2, 5):
    A = HMM.create_zero_mat(n_states, n_states)
    B = HMM.create_zero_mat(n_states, K)
    pi = [0] * n_states
    hmm = HMM(n_states, K)
    A, B, pi = hmm.learning(obs)
    print('=====states:',n_states,'=====')
    print('A:', A)
    print('B:', B)
    print('pi:', pi)
# Out:
# =====states: 2 =====
# A: [[0.8277664529959562, 0.17223354700404245], [0.30474335661887286, 0.6952566433811284]]
# B: [[0.013544413127398592, 0.2959109645553157, 0.31510008278102153, 0.37544453953626217], [0.646401214307754, 0.16459260232227743, 0.0978176454784874, 0.09118853789148251]]
# pi: [3.8756653163344376e-41, 1.000000000000023]
# =====states: 3 =====
# A: [[0.5539201530240314, 0.10444244787104565, 0.3416373991049226], [0.3655298863293463, 0.4069835144278311, 0.22748659924282258], [0.05264795673146336, 0.16882165893032958, 0.7785303843382082]]
# B: [[0.7756760361351015, 0.04131099234782155, 0.09634994699491264, 0.08666302452216389], [0.30034270841584887, 0.4737484458530898, 0.13745144136917667, 0.08845740436188385], [0.0021291387637178923, 0.2534406294983202, 0.32952645091033994, 0.41490378082762336]]
# pi: [1.0000000000000027, 1.5779112416272286e-27, 1.1359106694767347e-131]
# =====states: 4 =====
# A: [[0.2079687810162991, 0.3148196217670856, 0.25654929187238656, 0.22066230534422987], [0.12102206265735165, 0.6340334165826739, 0.09430404217020776, 0.15064047858976617], [0.2301757028873834, 0.07743299676788744, 0.4419769852182183, 0.25041431512651297], [0.2777565244596359, 0.13040978917084636, 0.3381439498182053, 0.25368973655131277]]
# B: [[0.0583646027708693, 0.34867437803557516, 0.24785244539701198, 0.345108573796544], [0.7220539476436166, 0.14958853820465268, 0.08111410500500256, 0.04724340914672826], [0.0074755518723053326, 0.3044202920000896, 0.3450584664550759, 0.3430456896725305], [0.024985118866281266, 0.2246743272241217, 0.31090996954349065, 0.43943058436610627]]
# pi: [7.05986680433616e-48, 0.9999999999999978, 1.5472395252263635e-90, 2.1260353705937661e-66]
